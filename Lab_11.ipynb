# %% [markdown]
# <a href="https://colab.research.google.com/github/mkounkel/Auriga/blob/master/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 11 - Exoplanet detection

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Today we will look at our Solar system as an exoplanet. The cell below defines various constants, including an array of their masses, radii, semimajor axes, and inclinations (relative to the earth)

# %%
msun=1.989e30 #kg
rsun=6.96e8 #m
au=1.496e+11 #m
year=3.154e+7 #s
pc=3.086e+16 #m
mearth=5.972e+24 #kg
rearth=6.378e6 #m
g=6.67e-11 #SI
masses=np.array([0.055, 0.82, 1, 0.11, 318, 95, 14.5, 17.1])*mearth
sma=np.array([0.39, 0.72, 1, 1.52, 5.2, 9.54, 19.22, 30.06])*au
radii=np.array([0.382, 0.95, 1.0, 0.53, 11.2, 9.42, 4.01, 3.93])*rearth
incl=np.array([7.01, 3.39, 0, 1.85, 1.31, 2.49, 0.77, 1.77]) #deg

# %% [markdown]
# Assuming circular orbits, and assuming that we are looking at the orbit of the Earth edge-on (approximating all planets to be coplanar), determine the amplitude of the rotational velocity of all of the planets.

# %%
#put your code here

# %% [markdown]
# For each planet, plot a sinusoid representing their RV curve, with the width of the sinusoid corresponding to the orbital period of each planet and the amplitude corresponding to your calculation from earlier.

# %%
#put your code here

# %% [markdown]
# Repeat the plot above, but plot the radial velocity of the *Sun* as it responds to the movements of all of the individual the planets instead.

# %%
#put your code here

# %% [markdown]
# Calculate of the total radial velocity of the Sun over the period of 100 years, through adding all of the individual contributions that the Sun experiences at a given time from all 8 planets.

# %%
#put your code here

# %% [markdown]
# Compare this RV curve against the RV curve of
# 1) RV curve due to the planet that displaces the Sun most strongly
# 2) RV curve due to the top 2 planets that displace the Sun most strongly

# %%
#put your code here

# %% [markdown]
# #### Questions
# - Which planet has the strongest effect on the Sun
# - How long do you think you would need to monitor the Sun to infer the presense of this planet
# - How long do you think you would need to monitor the Sun to infer that there is more than one planet?
# - Assuming state-of-the-art spectrographs can offer the precision of 0.5 m/s, how many planets in total would you be able to detect, eventually? What would these planets be?
#
# #### Answers

# %% [markdown]
# -----
# Now let's construct a light curve for each planet. Consider the following geometry:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Point 1 occurs during first contact, when planet just 'touches' the limb star, point 2 would occur after the full ingress, when the outermost edge of the planet makes the contact with the limb of the star.
#
# The continuum flux of the star can be normalized to 1.
#
# When observing the planetary transit from very far away (i.e., from a different solar system), you don't need to worry about angles caused by different SMAs - the duration of the eclipse would be set by the orbital velocity of the planet traveling the distance that is approximately equivalent to the physical size of the star.
#
# Similarly, the fraction of the suppresed flux would be a ratio between the surface area of the planet vs the surface area of the star.
#
# Calculate the time it takes for each planet to move from point 1 to point 2, the time from point 2 to point 3, and the flux that would be measured between points 2 & 3.

# %%
#put your code here

# %% [markdown]
# Plot the eclipses for the terrestrial planets on one plot, and the eclipses of Jovian planets on a different plot.

# %%
#put your code here

# %% [markdown]
# #### Question
# - Which planet produces the strongest eclipse?
# - Kepler space telescope has achieved sensitivity of ~30 parts-per-million for a Sun-like star with V<12 mag. Assuming this sensitivity, which planets would we be able to detect?
# - How does the eclipse duration depend on the distance of a planet to the star?
# - How does the eclipse strength depend on the distance of a planet to the star?
# - Here we assumed that the planet would be able to pass through the center of a star. How would any of the above change if the planet is transiting below or above the equator of the Sun?
#
# #### Answer

# %% [markdown]
# Detection of multiple planets in a same system requires a very small mutual inclination angle. Calculate the smallest possible scatter in inclination for each planet for its eclipses to be visible.

# %%
#put your code here

# %% [markdown]
# #### Question.
# Assume that the sensitivity of a telescope that is observing the Solar system from far away is sufficient to detect every single planetary eclipse caused by all 8 planets if they transit anywhere along the same line of sight as the Sun, and that the monitoring time is long enough that every planet would be able to complete at least 3 orbits. Consider the mutual inclinations of all of the planets relative to the ecliptic (given in the array in the second cell). Assuming that the alignment between the distant system and the Sun is such that they would be able to witness the Earth transiting in front of the Sun.
# - Eclipses from how many planets in total would they be able to detect?
# - How many planets might they infer to exist in our Solar system
#
# #### Answer

# %% [markdown]
# ----
# #### Reflection Questions
#
# - How long did this lab take you?
# - What were the areas that were easy?
# - What were the areas that presented a challenge?
#
# #### Reflections

# %% [markdown]
# ----
# # Extra credit
#
# Proxima centauri is the closest star to the Solar system, at a distance of 1.3 pc. Demonstrate that even if you are observing the Solar system from Proxima Cen, the eclipse duration that you can calculate using the angular speed of any planet transiting in front of the Sun is almost equivalent to the eclipse duration that you can calculate using the physical speed of that planet traveling the distance equivalent to the size of the Sun.

# %%
#put your code here
